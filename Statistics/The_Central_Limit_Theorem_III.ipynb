# %% [markdown]
# https://www.hackerrank.com/challenges/s10-the-central-limit-theorem-3

# %% [markdown]
# ![std_dev.JPG](attachment:std_dev.JPG)

# %%
from math import *

samplesize=float(input())
u1=float(input())
s1=float(input())
percent_dis=float(input())
z=float(input())

#u=samplesize*u1
s=s1/sqrt(samplesize)

print(round(u1-(z*s),2))
print(round(u1+(z*s),2))
# Out:
# 100
# 500
# 80
# 0.95
# 1.96
# 484.32
# 515.68
